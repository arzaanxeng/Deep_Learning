# %% [markdown]
# # Notebook 1

# %%
import numpy as np

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
# Input Features
X = np.array([[10,14,18,16]])

# %%
# Initialising the weights
W = np.random.randn(4,3)
W
# Out:
# array([[ 0.54767458,  0.3321941 ,  0.78728503],
#        [-2.21246422, -1.22853297,  1.09569202],
#        [ 0.52538246,  1.02056597, -1.66735531],
#        [-0.64909069, -0.18256249, -0.98494436]])

# %%
# Initialising the bias
B = np.random.rand(1,3)
B
# Out:
# array([[0.92255403, 0.92421282, 0.5534021 ]])

# %%
Z = X@(W)+ B
A = sigmoid(Z)

# %%
print("X shape :", X.shape)
print("W shape :", W.shape)
print("B shape :", B.shape)
print("Z shape :", Z.shape)
print("A shape :", A.shape)
# Out:
# X shape : (1, 4)
# W shape : (4, 3)
# B shape : (1, 3)
# Z shape : (1, 3)
# A shape : (1, 3)

# %%
A
# Out:
# array([[8.39180105e-12, 9.23852474e-01, 2.77398865e-10]])
